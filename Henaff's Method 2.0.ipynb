# %%
import torch, torch.autograd as autograd
import torch.nn as nn, torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable as avar
    
from SimpleTask import SimpleGridTask
from TransportTask import TransportTask
from NavTask import NavigationTask
from SeqData import SeqData
from LSTMFM import LSTMForwardModel

import os, sys, pickle, numpy as np, numpy.random as npr, random as r

# %%
f_model_name = 'LSTM_FM_1_99'    
s = 'navigation' # 'transport'
trainf, validf = s + "-data-train-small.pickle", s + "-data-test-small.pickle"
print('Reading Data')
train, valid = SeqData(trainf), SeqData(validf)
# Out:
# Reading Data
# Reading navigation-data-train-small.pickle
# 	Built
# Reading navigation-data-test-small.pickle
# 	Built

# %%
fm = LSTMForwardModel(train.lenOfInput,train.lenOfState)
fm.load_state_dict( torch.load(f_model_name) )

# %%
class HenaffPlanner():

    def __init__(self,forward_model,env, maxNumActions=1,noiseSigma=0.0,startNoiseSigma=0.1,niters=200):
        # Parameters
        self.sigma = noiseSigma
        self.start_sigma = startNoiseSigma
        self.nacts = maxNumActions
        self.niters = niters
        # The forward model
        self.f = forward_model
        # Stop forward model from training
        for p in self.f.parameters(): p.requires_grad = False
        # Get shapes from forward model
        self.state_size = self.f.stateSize
        self.action_size = self.f.inputSize - self.f.stateSize
        self.env = env

    def generatePlan(self,
            start_state,         # The starting state of the agent
            eta=0.0003,            # The learning rate given to ADAM
            noiseSigma=None,     # Noise strength on inputs. Overwrites the default setting from the init
            niters=None,         # Number of optimization iterations. Overwrites the default setting from the init
            goal_state=None,     # Use to specify a goal state manually (instead of reading it from a given state)
            useCE=False,         # Specifies use of the cross-entropy loss, taken over subvectors of the state
            verbose=False,       # Specifies verbosity
            extraVerbose=False,  # Specifies extra verbosity
            useGumbel=True,      # Whether to use Gumbel-Softmax in the action sampling
            temp=0.01,           # The temperature of the Gumbel-Softmax method
            lambda_h=0.0,        # Specify the strength of entropy regularization (negative values encourage entropy)
            useIntDistance=False
        ):

        # Other settings
        useIntDistance = False # Note: does not apply if using CE
        useMSE_loss = (not useIntDistance) and (not useCE)
        if not noiseSigma is None: self.sigma = noiseSigma
        if not niters is None: self.niters = niters

        # Initialize random actions and optimizer
        x_t = avar( torch.randn(self.nacts, self.action_size) * self.start_sigma, requires_grad=True )
        optimizer = torch.optim.Adam( [x_t], lr=eta )
        # Choose loss function
        if useCE:
            lossf = nn.CrossEntropyLoss()
            if verbose: print('Using CE loss')
        elif useMSE_loss:
            if verbose: print('Using MSE loss')
            lossf = nn.MSELoss()
        else:
            if verbose: print('Using int distance loss')

        # Set goal state
        deconStartState = self.env.deconcatenateOneHotStateVector(start_state)
        if goal_state is None:
            gx, gy = avar(torch.FloatTensor(deconStartState[-2])), avar(torch.FloatTensor(deconStartState[-1]))
        else: print('Not yet implemented'); sys.exit(0)

        # Indices of start state position
        sindx = avar(torch.FloatTensor(deconStartState[0])).max(0)[1]
        sindy = avar(torch.FloatTensor(deconStartState[1])).max(0)[1]

        # Indices of goal state position
        indx, indy = gx.max(0)[1], gy.max(0)[1]

        # Start optimization loop
        for i in range(self.niters):
            # Generate soft action sequence
            epsilon = avar( torch.randn(self.nacts, self.action_size) * self.sigma )
            # Add noise to current action sequence
            y_t = x_t + epsilon
            # Softmax inputs to get current soft actions
            a_t = F.softmax( y_t, dim=1 )
            # Compute predicted state
            #currState = avar(torch.FloatTensor(start_state)).unsqueeze(0)
            # Loop over actions to obtain predicted state
            self.f.reInitialize(1)
            currState, intStates = self.f.forward(start_state, a_t, self.nacts)
            # Now have final (predicted) result of action sequence
            # Extract predicted position of current state
            pvx = currState[0:15] 
            pvy = currState[15:30] 
            # Compute loss
            if useCE: # Cross-entropy loss
                lossx = lossf(pvx.view(1,pvx.shape[0]), indx) 
                lossy = lossf(pvy.view(1,pvy.shape[0]), indy)
            elif useIntDistance: # Integer distance loss
                ints = avar( torch.FloatTensor( list(range(15)) ) )
                prx = torch.sum( ints * pvx )
                pry = torch.sum( ints * pvy )
                lossx = (1.0/15.0) * (prx - indx.data[0]).pow(2)
                lossy = (1.0/15.0) * (pry - indy.data[0]).pow(2) 
            else: # Using MSE loss via one-hot pos
                lossx = lossf(pvx, gx)
                lossy = lossf(pvy, gy)
            # Entropy penalty
            H = -torch.sum( torch.sum( a_t*torch.log(a_t) , dim = 1 ) )
            # Final loss function 
            loss = lossx + lossy + lambda_h * H
            # Print status
            if extraVerbose:
                a_inds = ",".join([ str(a.max(dim=0)[1].data[0]) for a in a_t  ]) 
                print(i,'->','Lx =',lossx.data[0],', Ly =',lossy.data[0],', H =',H.data[0],', TL =',loss.data[0],', A =',a_inds)
            # Clear the optimizer gradient
            optimizer.zero_grad()
            # Back-prop the errors to get the new gradients
            loss.backward(retain_graph=True)
            optimizer.step()
            # Print the predicted result at the current iteration
            if extraVerbose:
                print('Predicted End:',pvx.max(0)[1].data[0],pvy.max(0)[1].data[0])
            # Ensure the x_t gradients are cleared
            #x_t.grad.data.zero_()
        # Print and analyze the final plan, if desired
        if verbose:
            print('\nEnd\n')
            print('Actions')
            for k in range(0,self.nacts):
                action = F.softmax( x_t[k,:], dim=0 )
                print(action.max(0)[1].data[0],end=' -> ')
                print(NavigationTask.actions[action.max(0)[1].data[0]],end=' ')
                print(action.data)
            print('--')
            print('START ',sindx.data[0],sindy.data[0])
            print('TARGET END ',indx.data[0],indy.data[0])
            print('PREDICTED END',pvx.max(0)[1].data[0], pvy.max(0)[1].data[0])
            print('--')
        # Return the final action sequence 
        return [ x.max(0)[1].data[0] for x in x_t ]

# %%
start = np.zeros(64)
start[0] = 1
start[15] = 1
start[15+15] = 1
start[15+15+4+5] = 1
start[15+15+4+15+8] = 1
env = NavigationTask()
#print(fm.env.deconcatenateOneHotStateVector(start))
print('Building planner')
planner = HenaffPlanner(fm,env,maxNumActions=6)
print('Starting generation')
actions = planner.generatePlan(
                    start,
                    eta=0.3,
                    noiseSigma=1.0,
                    niters=300,
                    goal_state=None,
                    useCE=True,
                    verbose=True,
                    extraVerbose=False,
                    useGumbel=True,
                    temp=0.1,
                    lambda_h=-0.005,
                    useIntDistance=False
                    )
print('FINAL ACTIONS:', actions)
# Out:
# Building planner
# Starting generation
# Using CE loss
#
# End
#
# Actions
# 8 -> Move_4
#  8.3581e-05
#  4.5191e-04
#  2.0505e-05
#  2.4500e-05
#  7.8348e-06
#  3.0349e-04
#  4.4709e-03
#  1.9184e-02
#  9.7418e-01
#  1.2683e-03
# [torch.FloatTensor of size 10]
#
# 7 -> Move_3
#  2.6539e-06
#  4.5654e-06
#  2.7681e-06
#  3.8603e-07
#  1.0370e-06
#  1.7195e-02
#  6.7890e-05
#  9.8235e-01
#  1.9338e-04
#  1.8567e-04
# [torch.FloatTensor of size 10]
#
# 5 -> Move_1
#  0.0046
#  0.0003
#  0.0000
#  0.0001
#  0.0052
#  0.9892
#  0.0001
#  0.0003
#  0.0001
#  0.0001
# [torch.FloatTensor of size 10]
#
# 2 -> Face_east
#  5.1321e-06
#  5.9366e-05
#  9.9977e-01
#  3.3542e-06
#  1.1887e-04
#  8.4190e-06
#  1.0562e-05
#  9.3773e-06
#  1.1992e-05
#  2.3158e-06
# [torch.FloatTensor of size 10]
#
# 2 -> Face_east
#  7.4292e-06
#  5.8189e-06
#  9.9992e-01
#  2.3299e-06
#  1.8662e-05
#  1.0771e-05
#  4.7657e-06
#  9.9611e-06
#  8.2497e-06
#  7.0630e-06
# [torch.FloatTensor of size 10]
#
# 9 -> Move_5
#  4.8282e-06
#  3.5284e-06
#  8.1347e-06
#  4.9042e-06
#  5.0334e-06
#  2.5757e-06
#  2.2829e-06
#  1.6245e-05
#  1.5745e-05
#  9.9994e-01
# [torch.FloatTensor of size 10]
#
# --
# START  0 0
# TARGET END  5 8
# PREDICTED END 5 8
# --
# FINAL ACTIONS: [8, 7, 5, 2, 2, 9]

# %%
##################### Hyper-params #####################
# lambda_hs = [0.0,0.01,-0.01,0.05,-0.05,0.005,-0.005]            # Entropy strength
# etas = [0.5,0.25,0.1,0.05,0.025,0.01,0.005,0.001,0.0005]        # Learning rate
# useGumbels = [True,False]                                       # Whether to use Gumbel-softmax
# temperatures = [0.1,0.01,0.001,1.0]                             # Temperature for Gumbel-softmax
# noiseSigmas = [0.0,0.01,0.02,0.05,0.1,0.25,0.5,0.75,1.0,1.25]   # Noise strength on input
## Init try
# lambda_hs = [0.0,0.005,-0.005]                                  # Entropy strength
# etas = [0.5,0.25,0.1,0.05,0.025,0.01,0.005,0.001,0.0005]        # Learning rate
# useGumbels = [True,False]                                       # Whether to use Gumbel-softmax
# temperatures = [0.1,0.01,0.001]                             # Temperature for Gumbel-softmax
# noiseSigmas = [0.0,0.05,0.1,0.5,1.0]   # Noise strength on input
## Only use ones with decent results
lambda_hs = [0.0,-0.005, 0.005]                                  # Entropy strength
etas = [0.2,0.3,1,0.1, 0.5]        # Learning rate
useGumbels = [True, False]                                       # Whether to use Gumbel-softmax
temperatures = [2,1, 10, 0.1,0.001]                             # Temperature for Gumbel-softmax
noiseSigmas = [0.5,0.05, 1.0, 0.75]   # Noise strength on input
########################################################

###### Settings ######
niters = 150
verbose = False
extraVerbose = False
numRepeats = 5
fileToWriteTo = 'hyper-param-results.txt' # Set to None to do no writing
distType = 1 # 0 = MSE, 1 = CE, 2 = dist
######################

# Build an env with the given INT inputs
def generateTask(px,py,orien,gx,gy):
    direction = NavigationTask.oriens[orien]
    gs = np.array([gx, gy])
    env = NavigationTask(agent_start_pos=[np.array([px,py]), direction],goal_pos=gs)
    return env

# Function for running a single suite of tests (on one hyper-param set)
def runTests(lh,eta,noiseLevel,ug,cnum,temp=None,distType=0):
    # Define tasks
    tasks = [
        [3, generateTask(0,0,0,5,5)],
        [4, generateTask(5,5,1,0,9)],
        [5, generateTask(3,2,2,7,7)],
    ]
    # Choose dist type
    if distType == 0:   useCE = False; intDist = False
    elif distType == 1: useCE = True;  intDist = False
    elif distType == 2: useCE = False; intDist = True 
    # Display status
    wstring = cnum + ',lambda_h=' + str(lh) + ',eta=' + str(eta) + ',sigma=' + str(noiseLevel) + ',dType=' + str(distType) + ',ug=' + str(ug)
    if ug: wstring += ',temp=' + str(temp) 
    # For each tasks, repeated a few times, attempt to solve the problem
    score, tot = 0, 0
    for i, task in enumerate(tasks):
        #print(i)
        for _ in range(numRepeats):
            planner = HenaffPlanner(fm,env,maxNumActions=task[0])
            cenv = task[1]
            actions = planner.generatePlan(
                    cenv.getStateRep(oneHotOutput=True),
                    eta=eta,
                    noiseSigma=noiseLevel,
                    niters=niters,
                    goal_state=None,
                    useCE=True,
                    verbose=verbose,
                    extraVerbose=extraVerbose,
                    useGumbel=ug,
                    temp=temp,
                    lambda_h=lh,
                    useIntDistance=intDist )
            # Check for correctness
            for a in actions: cenv.performAction( a )
            r = cenv.getReward()
            correct = (r==1)
            tot += 1
            if correct: score += 1
    wstring += ' -> Score:' + str(score) + '/' + str(tot)
    print(wstring)
    # Write output
    if not fileToWriteTo is None:
        with open(fileToWriteTo,'a') as filehandle:
            filehandle.write( wstring + '\n' )

# Run tasks over all hyper-parameter settings
N_p, cp = len(lambda_hs)*len(etas)*len(noiseSigmas)*(1 + len(temperatures)), 1
for lambda_h in lambda_hs:
    for eta in etas:
        for noiseLevel in noiseSigmas:
            for ug in useGumbels:
                if ug:
                    for temp in temperatures: 
                        ps = str(cp) + '/' + str(N_p)
                        runTests(lambda_h,eta,noiseLevel,ug,ps,temp,distType=distType)
                        cp += 1
                else: 
                    ps = str(cp) + '/' + str(N_p)
                    runTests(lambda_h,eta,noiseLevel,ug,ps,distType=distType)
                    cp += 1
# Out:
# 1/360,lambda_h=0.0,eta=0.2,sigma=0.5,dType=1,ug=True,temp=2 -> Score:5/15
# 2/360,lambda_h=0.0,eta=0.2,sigma=0.5,dType=1,ug=True,temp=1 -> Score:10/15
# 3/360,lambda_h=0.0,eta=0.2,sigma=0.5,dType=1,ug=True,temp=10 -> Score:9/15
# 4/360,lambda_h=0.0,eta=0.2,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:8/15
# 5/360,lambda_h=0.0,eta=0.2,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:8/15
# 6/360,lambda_h=0.0,eta=0.2,sigma=0.5,dType=1,ug=False -> Score:9/15
# 7/360,lambda_h=0.0,eta=0.2,sigma=0.05,dType=1,ug=True,temp=2 -> Score:5/15
# 8/360,lambda_h=0.0,eta=0.2,sigma=0.05,dType=1,ug=True,temp=1 -> Score:5/15
# 9/360,lambda_h=0.0,eta=0.2,sigma=0.05,dType=1,ug=True,temp=10 -> Score:8/15
# 10/360,lambda_h=0.0,eta=0.2,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:5/15
# 11/360,lambda_h=0.0,eta=0.2,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:5/15
# 12/360,lambda_h=0.0,eta=0.2,sigma=0.05,dType=1,ug=False -> Score:5/15
# 13/360,lambda_h=0.0,eta=0.2,sigma=1.0,dType=1,ug=True,temp=2 -> Score:9/15
# 14/360,lambda_h=0.0,eta=0.2,sigma=1.0,dType=1,ug=True,temp=1 -> Score:13/15
# 15/360,lambda_h=0.0,eta=0.2,sigma=1.0,dType=1,ug=True,temp=10 -> Score:13/15
# 16/360,lambda_h=0.0,eta=0.2,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:13/15
# 17/360,lambda_h=0.0,eta=0.2,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:9/15
# 18/360,lambda_h=0.0,eta=0.2,sigma=1.0,dType=1,ug=False -> Score:10/15
# 19/360,lambda_h=0.0,eta=0.2,sigma=0.75,dType=1,ug=True,temp=2 -> Score:9/15
# 20/360,lambda_h=0.0,eta=0.2,sigma=0.75,dType=1,ug=True,temp=1 -> Score:13/15
# 21/360,lambda_h=0.0,eta=0.2,sigma=0.75,dType=1,ug=True,temp=10 -> Score:9/15
# 22/360,lambda_h=0.0,eta=0.2,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:9/15
# 23/360,lambda_h=0.0,eta=0.2,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:10/15
# 24/360,lambda_h=0.0,eta=0.2,sigma=0.75,dType=1,ug=False -> Score:8/15
# 25/360,lambda_h=0.0,eta=0.3,sigma=0.5,dType=1,ug=True,temp=2 -> Score:9/15
# 26/360,lambda_h=0.0,eta=0.3,sigma=0.5,dType=1,ug=True,temp=1 -> Score:5/15
# 27/360,lambda_h=0.0,eta=0.3,sigma=0.5,dType=1,ug=True,temp=10 -> Score:8/15
# 28/360,lambda_h=0.0,eta=0.3,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:9/15
# 29/360,lambda_h=0.0,eta=0.3,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:7/15
# 30/360,lambda_h=0.0,eta=0.3,sigma=0.5,dType=1,ug=False -> Score:13/15
# 31/360,lambda_h=0.0,eta=0.3,sigma=0.05,dType=1,ug=True,temp=2 -> Score:8/15
# 32/360,lambda_h=0.0,eta=0.3,sigma=0.05,dType=1,ug=True,temp=1 -> Score:9/15
# 33/360,lambda_h=0.0,eta=0.3,sigma=0.05,dType=1,ug=True,temp=10 -> Score:5/15
# 34/360,lambda_h=0.0,eta=0.3,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:5/15
# 35/360,lambda_h=0.0,eta=0.3,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:5/15
# 36/360,lambda_h=0.0,eta=0.3,sigma=0.05,dType=1,ug=False -> Score:8/15
# 37/360,lambda_h=0.0,eta=0.3,sigma=1.0,dType=1,ug=True,temp=2 -> Score:5/15
# 38/360,lambda_h=0.0,eta=0.3,sigma=1.0,dType=1,ug=True,temp=1 -> Score:12/15
# 39/360,lambda_h=0.0,eta=0.3,sigma=1.0,dType=1,ug=True,temp=10 -> Score:10/15
# 40/360,lambda_h=0.0,eta=0.3,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:12/15
# 41/360,lambda_h=0.0,eta=0.3,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:14/15
# 42/360,lambda_h=0.0,eta=0.3,sigma=1.0,dType=1,ug=False -> Score:13/15
# 43/360,lambda_h=0.0,eta=0.3,sigma=0.75,dType=1,ug=True,temp=2 -> Score:5/15
# 44/360,lambda_h=0.0,eta=0.3,sigma=0.75,dType=1,ug=True,temp=1 -> Score:10/15
# 45/360,lambda_h=0.0,eta=0.3,sigma=0.75,dType=1,ug=True,temp=10 -> Score:9/15
# 46/360,lambda_h=0.0,eta=0.3,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:5/15
# 47/360,lambda_h=0.0,eta=0.3,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:13/15
# 48/360,lambda_h=0.0,eta=0.3,sigma=0.75,dType=1,ug=False -> Score:7/15
# 49/360,lambda_h=0.0,eta=1,sigma=0.5,dType=1,ug=True,temp=2 -> Score:12/15
# 50/360,lambda_h=0.0,eta=1,sigma=0.5,dType=1,ug=True,temp=1 -> Score:8/15
# 51/360,lambda_h=0.0,eta=1,sigma=0.5,dType=1,ug=True,temp=10 -> Score:5/15
# 52/360,lambda_h=0.0,eta=1,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:10/15
# 53/360,lambda_h=0.0,eta=1,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:8/15
# 54/360,lambda_h=0.0,eta=1,sigma=0.5,dType=1,ug=False -> Score:12/15
# 55/360,lambda_h=0.0,eta=1,sigma=0.05,dType=1,ug=True,temp=2 -> Score:8/15
# 56/360,lambda_h=0.0,eta=1,sigma=0.05,dType=1,ug=True,temp=1 -> Score:8/15
# 57/360,lambda_h=0.0,eta=1,sigma=0.05,dType=1,ug=True,temp=10 -> Score:8/15
# 58/360,lambda_h=0.0,eta=1,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:7/15
# 59/360,lambda_h=0.0,eta=1,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:10/15
# 60/360,lambda_h=0.0,eta=1,sigma=0.05,dType=1,ug=False -> Score:8/15
# 61/360,lambda_h=0.0,eta=1,sigma=1.0,dType=1,ug=True,temp=2 -> Score:12/15
# 62/360,lambda_h=0.0,eta=1,sigma=1.0,dType=1,ug=True,temp=1 -> Score:8/15
# 63/360,lambda_h=0.0,eta=1,sigma=1.0,dType=1,ug=True,temp=10 -> Score:11/15
# 64/360,lambda_h=0.0,eta=1,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:2/15
# 65/360,lambda_h=0.0,eta=1,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:10/15
# 66/360,lambda_h=0.0,eta=1,sigma=1.0,dType=1,ug=False -> Score:10/15
# 67/360,lambda_h=0.0,eta=1,sigma=0.75,dType=1,ug=True,temp=2 -> Score:13/15
# 68/360,lambda_h=0.0,eta=1,sigma=0.75,dType=1,ug=True,temp=1 -> Score:9/15
# 69/360,lambda_h=0.0,eta=1,sigma=0.75,dType=1,ug=True,temp=10 -> Score:8/15
# 70/360,lambda_h=0.0,eta=1,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:10/15
# 71/360,lambda_h=0.0,eta=1,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:12/15
# 72/360,lambda_h=0.0,eta=1,sigma=0.75,dType=1,ug=False -> Score:12/15
# 73/360,lambda_h=0.0,eta=0.1,sigma=0.5,dType=1,ug=True,temp=2 -> Score:11/15
# 74/360,lambda_h=0.0,eta=0.1,sigma=0.5,dType=1,ug=True,temp=1 -> Score:8/15
# 75/360,lambda_h=0.0,eta=0.1,sigma=0.5,dType=1,ug=True,temp=10 -> Score:8/15
# 76/360,lambda_h=0.0,eta=0.1,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:7/15
# 77/360,lambda_h=0.0,eta=0.1,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:8/15
# 78/360,lambda_h=0.0,eta=0.1,sigma=0.5,dType=1,ug=False -> Score:8/15
# 79/360,lambda_h=0.0,eta=0.1,sigma=0.05,dType=1,ug=True,temp=2 -> Score:5/15
# 80/360,lambda_h=0.0,eta=0.1,sigma=0.05,dType=1,ug=True,temp=1 -> Score:5/15
# 81/360,lambda_h=0.0,eta=0.1,sigma=0.05,dType=1,ug=True,temp=10 -> Score:5/15
# 82/360,lambda_h=0.0,eta=0.1,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:5/15
# 83/360,lambda_h=0.0,eta=0.1,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:5/15
# 84/360,lambda_h=0.0,eta=0.1,sigma=0.05,dType=1,ug=False -> Score:5/15
# 85/360,lambda_h=0.0,eta=0.1,sigma=1.0,dType=1,ug=True,temp=2 -> Score:9/15
# 86/360,lambda_h=0.0,eta=0.1,sigma=1.0,dType=1,ug=True,temp=1 -> Score:13/15
# 87/360,lambda_h=0.0,eta=0.1,sigma=1.0,dType=1,ug=True,temp=10 -> Score:7/15
# 88/360,lambda_h=0.0,eta=0.1,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:12/15
# 89/360,lambda_h=0.0,eta=0.1,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:13/15
# 90/360,lambda_h=0.0,eta=0.1,sigma=1.0,dType=1,ug=False -> Score:13/15
# 91/360,lambda_h=0.0,eta=0.1,sigma=0.75,dType=1,ug=True,temp=2 -> Score:5/15
# 92/360,lambda_h=0.0,eta=0.1,sigma=0.75,dType=1,ug=True,temp=1 -> Score:9/15
# 93/360,lambda_h=0.0,eta=0.1,sigma=0.75,dType=1,ug=True,temp=10 -> Score:9/15
# 94/360,lambda_h=0.0,eta=0.1,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:5/15
# 95/360,lambda_h=0.0,eta=0.1,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:5/15
# 96/360,lambda_h=0.0,eta=0.1,sigma=0.75,dType=1,ug=False -> Score:8/15
# 97/360,lambda_h=0.0,eta=0.5,sigma=0.5,dType=1,ug=True,temp=2 -> Score:10/15
# 98/360,lambda_h=0.0,eta=0.5,sigma=0.5,dType=1,ug=True,temp=1 -> Score:8/15
# 99/360,lambda_h=0.0,eta=0.5,sigma=0.5,dType=1,ug=True,temp=10 -> Score:5/15
# 100/360,lambda_h=0.0,eta=0.5,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:8/15
# 101/360,lambda_h=0.0,eta=0.5,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:9/15
# 102/360,lambda_h=0.0,eta=0.5,sigma=0.5,dType=1,ug=False -> Score:11/15
# 103/360,lambda_h=0.0,eta=0.5,sigma=0.05,dType=1,ug=True,temp=2 -> Score:8/15
# 104/360,lambda_h=0.0,eta=0.5,sigma=0.05,dType=1,ug=True,temp=1 -> Score:9/15
# 105/360,lambda_h=0.0,eta=0.5,sigma=0.05,dType=1,ug=True,temp=10 -> Score:9/15
# 106/360,lambda_h=0.0,eta=0.5,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:5/15
# 107/360,lambda_h=0.0,eta=0.5,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:9/15
# 108/360,lambda_h=0.0,eta=0.5,sigma=0.05,dType=1,ug=False -> Score:8/15
# 109/360,lambda_h=0.0,eta=0.5,sigma=1.0,dType=1,ug=True,temp=2 -> Score:7/15
# 110/360,lambda_h=0.0,eta=0.5,sigma=1.0,dType=1,ug=True,temp=1 -> Score:13/15
# 111/360,lambda_h=0.0,eta=0.5,sigma=1.0,dType=1,ug=True,temp=10 -> Score:11/15
# 112/360,lambda_h=0.0,eta=0.5,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:10/15
# 113/360,lambda_h=0.0,eta=0.5,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:11/15
# 114/360,lambda_h=0.0,eta=0.5,sigma=1.0,dType=1,ug=False -> Score:11/15
# 115/360,lambda_h=0.0,eta=0.5,sigma=0.75,dType=1,ug=True,temp=2 -> Score:5/15
# 116/360,lambda_h=0.0,eta=0.5,sigma=0.75,dType=1,ug=True,temp=1 -> Score:9/15
# 117/360,lambda_h=0.0,eta=0.5,sigma=0.75,dType=1,ug=True,temp=10 -> Score:7/15
# 118/360,lambda_h=0.0,eta=0.5,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:9/15
# 119/360,lambda_h=0.0,eta=0.5,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:8/15
# 120/360,lambda_h=0.0,eta=0.5,sigma=0.75,dType=1,ug=False -> Score:10/15
# 121/360,lambda_h=-0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=2 -> Score:5/15
# 122/360,lambda_h=-0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=1 -> Score:5/15
# 123/360,lambda_h=-0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=10 -> Score:10/15
# 124/360,lambda_h=-0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:9/15
# 125/360,lambda_h=-0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:5/15
# 126/360,lambda_h=-0.005,eta=0.2,sigma=0.5,dType=1,ug=False -> Score:6/15
# 127/360,lambda_h=-0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=2 -> Score:5/15
# 128/360,lambda_h=-0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=1 -> Score:5/15
# 129/360,lambda_h=-0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=10 -> Score:5/15
# 130/360,lambda_h=-0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:5/15
# 131/360,lambda_h=-0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:6/15
# 132/360,lambda_h=-0.005,eta=0.2,sigma=0.05,dType=1,ug=False -> Score:5/15
# 133/360,lambda_h=-0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=2 -> Score:8/15
# 134/360,lambda_h=-0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=1 -> Score:9/15
# 135/360,lambda_h=-0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=10 -> Score:9/15
# 136/360,lambda_h=-0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:7/15
# 137/360,lambda_h=-0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:13/15
# 138/360,lambda_h=-0.005,eta=0.2,sigma=1.0,dType=1,ug=False -> Score:11/15
# 139/360,lambda_h=-0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=2 -> Score:9/15
# 140/360,lambda_h=-0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=1 -> Score:8/15
# 141/360,lambda_h=-0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=10 -> Score:9/15
# 142/360,lambda_h=-0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:5/15
# 143/360,lambda_h=-0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:9/15
# 144/360,lambda_h=-0.005,eta=0.2,sigma=0.75,dType=1,ug=False -> Score:8/15
# 145/360,lambda_h=-0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=2 -> Score:6/15
# 146/360,lambda_h=-0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=1 -> Score:7/15
# 147/360,lambda_h=-0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=10 -> Score:8/15
# 148/360,lambda_h=-0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:5/15
# 149/360,lambda_h=-0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:8/15
# 150/360,lambda_h=-0.005,eta=0.3,sigma=0.5,dType=1,ug=False -> Score:5/15
# 151/360,lambda_h=-0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=2 -> Score:5/15
# 152/360,lambda_h=-0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=1 -> Score:5/15
# 153/360,lambda_h=-0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=10 -> Score:5/15
# 154/360,lambda_h=-0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:5/15
# 155/360,lambda_h=-0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:5/15
# 156/360,lambda_h=-0.005,eta=0.3,sigma=0.05,dType=1,ug=False -> Score:5/15
# 157/360,lambda_h=-0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=2 -> Score:9/15
# 158/360,lambda_h=-0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=1 -> Score:12/15
# 159/360,lambda_h=-0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=10 -> Score:9/15
# 160/360,lambda_h=-0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:6/15
# 161/360,lambda_h=-0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:11/15
# 162/360,lambda_h=-0.005,eta=0.3,sigma=1.0,dType=1,ug=False -> Score:12/15
# 163/360,lambda_h=-0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=2 -> Score:9/15
# 164/360,lambda_h=-0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=1 -> Score:14/15
# 165/360,lambda_h=-0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=10 -> Score:9/15
# 166/360,lambda_h=-0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:11/15
# 167/360,lambda_h=-0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:13/15
# 168/360,lambda_h=-0.005,eta=0.3,sigma=0.75,dType=1,ug=False -> Score:9/15
# 169/360,lambda_h=-0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=2 -> Score:7/15
# 170/360,lambda_h=-0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=1 -> Score:9/15
# 171/360,lambda_h=-0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=10 -> Score:11/15
# 172/360,lambda_h=-0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:8/15
# 173/360,lambda_h=-0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:7/15
# 174/360,lambda_h=-0.005,eta=1,sigma=0.5,dType=1,ug=False -> Score:3/15
# 175/360,lambda_h=-0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=2 -> Score:4/15
# 176/360,lambda_h=-0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=1 -> Score:1/15
# 177/360,lambda_h=-0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=10 -> Score:5/15
# 178/360,lambda_h=-0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:3/15
# 179/360,lambda_h=-0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:4/15
# 180/360,lambda_h=-0.005,eta=1,sigma=0.05,dType=1,ug=False -> Score:5/15
# 181/360,lambda_h=-0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=2 -> Score:9/15
# 182/360,lambda_h=-0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=1 -> Score:13/15
# 183/360,lambda_h=-0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=10 -> Score:7/15
# 184/360,lambda_h=-0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:9/15
# 185/360,lambda_h=-0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:7/15
# 186/360,lambda_h=-0.005,eta=1,sigma=1.0,dType=1,ug=False -> Score:6/15
# 187/360,lambda_h=-0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=2 -> Score:8/15
# 188/360,lambda_h=-0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=1 -> Score:9/15
# 189/360,lambda_h=-0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=10 -> Score:11/15
# 190/360,lambda_h=-0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:9/15
# 191/360,lambda_h=-0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:9/15
# 192/360,lambda_h=-0.005,eta=1,sigma=0.75,dType=1,ug=False -> Score:7/15
# 193/360,lambda_h=-0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=2 -> Score:5/15
# 194/360,lambda_h=-0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=1 -> Score:5/15
# 195/360,lambda_h=-0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=10 -> Score:5/15
# 196/360,lambda_h=-0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:7/15
# 197/360,lambda_h=-0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:9/15
# 198/360,lambda_h=-0.005,eta=0.1,sigma=0.5,dType=1,ug=False -> Score:12/15
# 199/360,lambda_h=-0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=2 -> Score:5/15
# 200/360,lambda_h=-0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=1 -> Score:5/15
# 201/360,lambda_h=-0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=10 -> Score:5/15
# 202/360,lambda_h=-0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:5/15
# 203/360,lambda_h=-0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:5/15
# 204/360,lambda_h=-0.005,eta=0.1,sigma=0.05,dType=1,ug=False -> Score:5/15
# 205/360,lambda_h=-0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=2 -> Score:13/15
# 206/360,lambda_h=-0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=1 -> Score:12/15
# 207/360,lambda_h=-0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=10 -> Score:9/15
# 208/360,lambda_h=-0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:9/15
# 209/360,lambda_h=-0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:5/15
# 210/360,lambda_h=-0.005,eta=0.1,sigma=1.0,dType=1,ug=False -> Score:9/15
# 211/360,lambda_h=-0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=2 -> Score:5/15
# 212/360,lambda_h=-0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=1 -> Score:5/15
# 213/360,lambda_h=-0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=10 -> Score:5/15
# 214/360,lambda_h=-0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:10/15
# 215/360,lambda_h=-0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:5/15
# 216/360,lambda_h=-0.005,eta=0.1,sigma=0.75,dType=1,ug=False -> Score:5/15
# 217/360,lambda_h=-0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=2 -> Score:9/15
# 218/360,lambda_h=-0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=1 -> Score:10/15
# 219/360,lambda_h=-0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=10 -> Score:9/15
# 220/360,lambda_h=-0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:7/15
# 221/360,lambda_h=-0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:7/15
# 222/360,lambda_h=-0.005,eta=0.5,sigma=0.5,dType=1,ug=False -> Score:9/15
# 223/360,lambda_h=-0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=2 -> Score:7/15
# 224/360,lambda_h=-0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=1 -> Score:8/15
# 225/360,lambda_h=-0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=10 -> Score:11/15
# 226/360,lambda_h=-0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:5/15
# 227/360,lambda_h=-0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:6/15
# 228/360,lambda_h=-0.005,eta=0.5,sigma=0.05,dType=1,ug=False -> Score:9/15
# 229/360,lambda_h=-0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=2 -> Score:9/15
# 230/360,lambda_h=-0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=1 -> Score:10/15
# 231/360,lambda_h=-0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=10 -> Score:8/15
# 232/360,lambda_h=-0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:13/15
# 233/360,lambda_h=-0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:13/15
# 234/360,lambda_h=-0.005,eta=0.5,sigma=1.0,dType=1,ug=False -> Score:14/15
# 235/360,lambda_h=-0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=2 -> Score:9/15
# 236/360,lambda_h=-0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=1 -> Score:8/15
# 237/360,lambda_h=-0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=10 -> Score:14/15
# 238/360,lambda_h=-0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:9/15
# 239/360,lambda_h=-0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:8/15
# 240/360,lambda_h=-0.005,eta=0.5,sigma=0.75,dType=1,ug=False -> Score:9/15
# 241/360,lambda_h=0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=2 -> Score:9/15
# 242/360,lambda_h=0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=1 -> Score:8/15
# 243/360,lambda_h=0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=10 -> Score:8/15
# 244/360,lambda_h=0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:8/15
# 245/360,lambda_h=0.005,eta=0.2,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:9/15
# 246/360,lambda_h=0.005,eta=0.2,sigma=0.5,dType=1,ug=False -> Score:7/15
# 247/360,lambda_h=0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=2 -> Score:9/15
# 248/360,lambda_h=0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=1 -> Score:5/15
# 249/360,lambda_h=0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=10 -> Score:8/15
# 250/360,lambda_h=0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:8/15
# 251/360,lambda_h=0.005,eta=0.2,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:9/15
# 252/360,lambda_h=0.005,eta=0.2,sigma=0.05,dType=1,ug=False -> Score:8/15
# 253/360,lambda_h=0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=2 -> Score:12/15
# 254/360,lambda_h=0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=1 -> Score:9/15
# 255/360,lambda_h=0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=10 -> Score:13/15
# 256/360,lambda_h=0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:9/15
# 257/360,lambda_h=0.005,eta=0.2,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:13/15
# 258/360,lambda_h=0.005,eta=0.2,sigma=1.0,dType=1,ug=False -> Score:14/15
# 259/360,lambda_h=0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=2 -> Score:7/15
# 260/360,lambda_h=0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=1 -> Score:12/15
# 261/360,lambda_h=0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=10 -> Score:10/15
# 262/360,lambda_h=0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:10/15
# 263/360,lambda_h=0.005,eta=0.2,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:9/15
# 264/360,lambda_h=0.005,eta=0.2,sigma=0.75,dType=1,ug=False -> Score:7/15
# 265/360,lambda_h=0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=2 -> Score:6/15
# 266/360,lambda_h=0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=1 -> Score:13/15
# 267/360,lambda_h=0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=10 -> Score:10/15
# 268/360,lambda_h=0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:10/15
# 269/360,lambda_h=0.005,eta=0.3,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:12/15
# 270/360,lambda_h=0.005,eta=0.3,sigma=0.5,dType=1,ug=False -> Score:10/15
# 271/360,lambda_h=0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=2 -> Score:5/15
# 272/360,lambda_h=0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=1 -> Score:8/15
# 273/360,lambda_h=0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=10 -> Score:11/15
# 274/360,lambda_h=0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:5/15
# 275/360,lambda_h=0.005,eta=0.3,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:5/15
# 276/360,lambda_h=0.005,eta=0.3,sigma=0.05,dType=1,ug=False -> Score:5/15
# 277/360,lambda_h=0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=2 -> Score:11/15
# 278/360,lambda_h=0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=1 -> Score:10/15
# 279/360,lambda_h=0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=10 -> Score:5/15
# 280/360,lambda_h=0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:7/15
# 281/360,lambda_h=0.005,eta=0.3,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:12/15
# 282/360,lambda_h=0.005,eta=0.3,sigma=1.0,dType=1,ug=False -> Score:9/15
# 283/360,lambda_h=0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=2 -> Score:9/15
# 284/360,lambda_h=0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=1 -> Score:12/15
# 285/360,lambda_h=0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=10 -> Score:9/15
# 286/360,lambda_h=0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:9/15
# 287/360,lambda_h=0.005,eta=0.3,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:4/15
# 288/360,lambda_h=0.005,eta=0.3,sigma=0.75,dType=1,ug=False -> Score:12/15
# 289/360,lambda_h=0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=2 -> Score:11/15
# 290/360,lambda_h=0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=1 -> Score:13/15
# 291/360,lambda_h=0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=10 -> Score:4/15
# 292/360,lambda_h=0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:4/15
# 293/360,lambda_h=0.005,eta=1,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:9/15
# 294/360,lambda_h=0.005,eta=1,sigma=0.5,dType=1,ug=False -> Score:7/15
# 295/360,lambda_h=0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=2 -> Score:4/15
# 296/360,lambda_h=0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=1 -> Score:9/15
# 297/360,lambda_h=0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=10 -> Score:7/15
# 298/360,lambda_h=0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:8/15
# 299/360,lambda_h=0.005,eta=1,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:3/15
# 300/360,lambda_h=0.005,eta=1,sigma=0.05,dType=1,ug=False -> Score:8/15
# 301/360,lambda_h=0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=2 -> Score:12/15
# 302/360,lambda_h=0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=1 -> Score:10/15
# 303/360,lambda_h=0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=10 -> Score:14/15
# 304/360,lambda_h=0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:4/15
# 305/360,lambda_h=0.005,eta=1,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:4/15
# 306/360,lambda_h=0.005,eta=1,sigma=1.0,dType=1,ug=False -> Score:1/15
# 307/360,lambda_h=0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=2 -> Score:3/15
# 308/360,lambda_h=0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=1 -> Score:5/15
# 309/360,lambda_h=0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=10 -> Score:5/15
# 310/360,lambda_h=0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:13/15
# 311/360,lambda_h=0.005,eta=1,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:2/15
# 312/360,lambda_h=0.005,eta=1,sigma=0.75,dType=1,ug=False -> Score:5/15
# 313/360,lambda_h=0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=2 -> Score:8/15
# 314/360,lambda_h=0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=1 -> Score:7/15
# 315/360,lambda_h=0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=10 -> Score:8/15
# 316/360,lambda_h=0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:8/15
# 317/360,lambda_h=0.005,eta=0.1,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:8/15
# 318/360,lambda_h=0.005,eta=0.1,sigma=0.5,dType=1,ug=False -> Score:8/15
# 319/360,lambda_h=0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=2 -> Score:9/15
# 320/360,lambda_h=0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=1 -> Score:9/15
# 321/360,lambda_h=0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=10 -> Score:9/15
# 322/360,lambda_h=0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:9/15
# 323/360,lambda_h=0.005,eta=0.1,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:8/15
# 324/360,lambda_h=0.005,eta=0.1,sigma=0.05,dType=1,ug=False -> Score:7/15
# 325/360,lambda_h=0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=2 -> Score:13/15
# 326/360,lambda_h=0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=1 -> Score:13/15
# 327/360,lambda_h=0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=10 -> Score:10/15
# 328/360,lambda_h=0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:8/15
# 329/360,lambda_h=0.005,eta=0.1,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:9/15
# 330/360,lambda_h=0.005,eta=0.1,sigma=1.0,dType=1,ug=False -> Score:9/15
# 331/360,lambda_h=0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=2 -> Score:9/15
# 332/360,lambda_h=0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=1 -> Score:13/15
# 333/360,lambda_h=0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=10 -> Score:9/15
# 334/360,lambda_h=0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:12/15
# 335/360,lambda_h=0.005,eta=0.1,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:10/15
# 336/360,lambda_h=0.005,eta=0.1,sigma=0.75,dType=1,ug=False -> Score:5/15
# 337/360,lambda_h=0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=2 -> Score:13/15
# 338/360,lambda_h=0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=1 -> Score:14/15
# 339/360,lambda_h=0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=10 -> Score:12/15
# 340/360,lambda_h=0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=0.1 -> Score:9/15
# 341/360,lambda_h=0.005,eta=0.5,sigma=0.5,dType=1,ug=True,temp=0.001 -> Score:10/15
# 342/360,lambda_h=0.005,eta=0.5,sigma=0.5,dType=1,ug=False -> Score:5/15
# 343/360,lambda_h=0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=2 -> Score:9/15
# 344/360,lambda_h=0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=1 -> Score:9/15
# 345/360,lambda_h=0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=10 -> Score:7/15
# 346/360,lambda_h=0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=0.1 -> Score:9/15
# 347/360,lambda_h=0.005,eta=0.5,sigma=0.05,dType=1,ug=True,temp=0.001 -> Score:9/15
# 348/360,lambda_h=0.005,eta=0.5,sigma=0.05,dType=1,ug=False -> Score:8/15
# 349/360,lambda_h=0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=2 -> Score:11/15
# 350/360,lambda_h=0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=1 -> Score:11/15
# 351/360,lambda_h=0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=10 -> Score:9/15
# 352/360,lambda_h=0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=0.1 -> Score:11/15
# 353/360,lambda_h=0.005,eta=0.5,sigma=1.0,dType=1,ug=True,temp=0.001 -> Score:12/15
# 354/360,lambda_h=0.005,eta=0.5,sigma=1.0,dType=1,ug=False -> Score:7/15
# 355/360,lambda_h=0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=2 -> Score:5/15
# 356/360,lambda_h=0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=1 -> Score:12/15
# 357/360,lambda_h=0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=10 -> Score:5/15
# 358/360,lambda_h=0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=0.1 -> Score:9/15
# 359/360,lambda_h=0.005,eta=0.5,sigma=0.75,dType=1,ug=True,temp=0.001 -> Score:6/15
# 360/360,lambda_h=0.005,eta=0.5,sigma=0.75,dType=1,ug=False -> Score:9/15
